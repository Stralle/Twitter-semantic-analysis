# %%
import nltk
import csv
import math
import sys
import numpy as np
import tensorflow as tf
from nltk.data import path
from nltk.stem import LancasterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize, regexp_tokenize
from random import random

#nltk.download()
string = "C:\\Users\\Strahinja\\AppData\\Roaming\\nltk_data"
path.append(string)

X, y = [], []
Xtest, ytest = [], []
Xval, yval = [], []

my_dict = {}

with open('train.csv', 'rt') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')
    next(reader, None)  # Skip header
    for row in reader:
        #if random() < 0.2:
        if random() < 0.6:
            y.append(int(row[1]))
            X.append(row[2].lower())
        else:
            if random() < 0.5:
                yval.append(int(row[1]))
                Xval.append(row[2].lower())
            else:
                ytest.append(int(row[1]))
                Xtest.append(row[2].lower())

            # print VAL
print(len(Xtest), ' ', len(X), ' ', len(Xval))

################# Processing training set ####################
for i in range(len(X)):
    words = regexp_tokenize(X[i], "[\w']+")

    stopword_list = set(stopwords.words('english'))
    words_filtered = [w for w in words if w not in stopword_list]

    final = []
    lancaster = LancasterStemmer()
    for word in words_filtered:
        final.insert(len(final), lancaster.stem(word))
        if final[len(final) - 1] in my_dict:
            if y[i] == 1:
                my_dict[final[len(final) - 1]] += 1
            else:
                my_dict[final[len(final) - 1]] -= 1
        else:
            if y[i] == 1:
                my_dict[final[len(final) - 1]] = 1
            else:
                my_dict[final[len(final) - 1]] = -1

    X[i] = final

print('Preprocesing training set finished')
################# END processing training set ####################


################# Processing validation set ####################
print('Preprocesing validation set')
for i in range(len(Xval)):
    words = regexp_tokenize(Xval[i], "[\w']+")

    stopword_list = set(stopwords.words('english'))
    words_filtered = [w for w in words if w not in stopword_list]

    final = []
    lancaster = LancasterStemmer()
    for word in words_filtered:
        final.insert(len(final), lancaster.stem(word))
    Xval[i] = final

print('Preprocesing validation set finished')
################# END processing validation set ####################

################# Processing test set ####################
print('Preprocesing test set')
for i in range(len(Xtest)):
    words = regexp_tokenize(Xtest[i], "[\w']+")

    stopword_list = set(stopwords.words('english'))
    words_filtered = [w for w in words if w not in stopword_list]

    final = []
    lancaster = LancasterStemmer()
    for word in words_filtered:
        final.insert(len(final), lancaster.stem(word))
    Xtest[i] = final

print('Preprocesing test set finished')
################# END processing test set ####################

Ptr, Ntr = [0] * len(X), [0] * len(X)
Pval, Nval = [0] * len(Xval), [0] * len(Xval)
Pts, Nts = [0] * len(Xtest), [0] * len(Xtest)

print('Start calculating 2d positions of tweets')
# Calculating 2d posiotion of every tweet in training samples
for i in range(len(X)):
    for word in X[i]:
        if word in my_dict:
            if my_dict[word] > 0:
                Ptr[i] += 1
            else:
                Ntr[i] += 1

# TODO: Maybe insert words from validation set in dictionary so it could improve accuracy in testing!?
# Calculating 2d position of every twet in validation samples
for i in range(len(Xval)):
    for word in Xval[i]:
        if word in my_dict:
            if my_dict[word] > 0:
                Pval[i] += 1
            else:
                Nval[i] += 1

# Calculating 2d position of every twet in test samples
for i in range(len(Xtest)):
    for word in Xtest[i]:
        if word in my_dict:
            if my_dict[word] > 0:
                Pts[i] += 1
            else:
                Nts[i] += 1

print('End calculating 2d positions of tweets')

#for i in range(10):
#    print(Ptr[i], ' ', Ntr[i])
#    print(Pts[i], ' ', Nts[i])

acc = 0.
k = 3

acc_val = 0.
best_k = 0

def sigma(c, b):
    if c == b:
        return 1
    else:
        return 0
    
big_f_weight = sys.float_info.max/1000;
    
############################## VALIDATION TO FIND BEST_K ON VALIDATION SET ###################################################

print('------------------- VALIDATION ------------------------')

for i in range(len(Pval)):
    
    if (i % (len(Pval)//7))==0:
        if acc_val < acc:
            acc_val = acc
            best_k = k
            
        print(' ')
        print('epoch: ', i ,';current acc: ', acc, ';best acc: ', acc_val, ';current k: ', k, ';best k: ', best_k)
        print(' ')
        
        acc = 0.
        k += 2
        
    
    dist = []
    weights = []

    for j in range(len(Ptr)):
        dist.append(math.sqrt(math.pow(Ptr[j] - Pval[i], 2) + math.pow(Ntr[j] - Nval[i], 2)))
        if dist[len(dist)-1] == 0:
            weights.append(big_f_weight)
        else:
            weights.append(1/dist[len(dist)-1])
        
    np_dist = np.array(dist)
    #Returns indices of k smallest distances
    k_smallest = np_dist.argsort()[:k]
    cls_cnt1 = 0
    cls_cnt0 = 0
    
    for j in range(len(k_smallest)):
        if y[k_smallest[j]] == 1:
            cls_cnt1 += weights[k_smallest[j]] * sigma(1, y[k_smallest[j]])
        else:
            cls_cnt0 += weights[k_smallest[j]] * sigma(0, y[k_smallest[j]])

    
    cls = 1 if cls_cnt1 > cls_cnt0 else 0
    
    match = False

    if cls == yval[i]:
        acc += 1.0 / (len(yval)//7)
        match = True

    if i % 500 == 0:
        print("[Test %3d] Prediction: %d, True Class: %d, Match: %d" % (i, cls, yval[i], match))

print("Validation training accuracy: ", acc_val)

acc = 0.
acc_val = 0.0

############################## TESTING FOR BEST_K ON VALIDATION SET ###########################################################

print('------------------- VALIDATION TESTING ------------------------')

for i in range(len(Pval)):
    
    dist = []
    weights = []

    for j in range(len(Ptr)):
        dist.append(math.sqrt(math.pow(Ptr[j] - Pval[i], 2) + math.pow(Ntr[j] - Nval[i], 2)))
        if dist[len(dist)-1] == 0:
            weights.append(big_f_weight)
        else:
            weights.append(1/dist[len(dist)-1])
        
    np_dist = np.array(dist)
    #Returns indices of k smallest distances
    k_smallest = np_dist.argsort()[:best_k]
    cls_cnt1 = 0
    cls_cnt0 = 0
    
    for j in range(len(k_smallest)):
        if y[k_smallest[j]] == 1:
            cls_cnt1 += weights[k_smallest[j]] * sigma(1, y[k_smallest[j]])
        else:
            cls_cnt0 += weights[k_smallest[j]] * sigma(0, y[k_smallest[j]])

    
    cls = 1 if cls_cnt1 > cls_cnt0 else 0
    
    match = False

    if cls == yval[i]:
        acc_val += 1.0 / len(yval)
        match = True

    if i % 500 == 0:
        print("[Test %3d] Prediction: %d, True Class: %d, Match: %d" % (i, cls, yval[i], match))

print("Validation Accuracy: ", acc_val)


print('------------------- FINAL TESTING ------------------------')
############################## TESTING FOR BEST_K ON TEST SET ###############################################################
acc = 0.
for i in range(len(Pts)):
    
    dist = []
    weights = []

    for j in range(len(Ptr)):
        dist.append(math.sqrt(math.pow(Ptr[j] - Pts[i], 2) + math.pow(Ntr[j] - Nts[i], 2)))
        if dist[len(dist)-1] == 0:
            weights.append(big_f_weight)
        else:
            weights.append(1/dist[len(dist)-1])
        
    np_dist = np.array(dist)
    #Returns indices of k smallest distances
    k_smallest = np_dist.argsort()[:best_k]
    cls_cnt1 = 0
    cls_cnt0 = 0
    
    for j in range(len(k_smallest)):
        if y[k_smallest[j]] == 1:
            cls_cnt1 += weights[k_smallest[j]] * sigma(1, y[k_smallest[j]])
        else:
            cls_cnt0 += weights[k_smallest[j]] * sigma(0, y[k_smallest[j]])

    
    cls = 1 if cls_cnt1 > cls_cnt0 else 0
    
    match = False

    if cls == ytest[i]:
        acc += 1.0 / len(ytest)
        match = True

    if i % 500 == 0:
        print("[Test %3d] Prediction: %d, True Class: %d, Match: %d" % (i, cls, ytest[i], match))

print("TESTING Accuracy: ", acc)


print('test: ', acc, ' val: ', acc_val)
# Out:
# 20201   59828   19960
# Preprocesing training set finished
# Preprocesing validation set
# Preprocesing validation set finished
# Preprocesing test set
# Preprocesing test set finished
# Start calculating 2d positions of tweets
# End calculating 2d positions of tweets
# ------------------- VALIDATION ------------------------
#
# epoch:  0 ;current acc:  0.0 ;best acc:  0.0 ;current k:  3 ;best k:  0
#
# [Test   0] Prediction: 0, True Class: 1, Match: 0
# [Test 500] Prediction: 0, True Class: 1, Match: 0
# [Test 1000] Prediction: 1, True Class: 1, Match: 1
# [Test 1500] Prediction: 1, True Class: 0, Match: 0
# [Test 2000] Prediction: 1, True Class: 1, Match: 1
# [Test 2500] Prediction: 1, True Class: 1, Match: 1
#
# epoch:  2851 ;current acc:  0.6832690284110616 ;best acc:  0.6832690284110616 ;current k:  5 ;best k:  5
#
# [Test 3000] Prediction: 1, True Class: 1, Match: 1
# [Test 3500] Prediction: 0, True Class: 1, Match: 0
# [Test 4000] Prediction: 0, True Class: 0, Match: 1
# [Test 4500] Prediction: 0, True Class: 1, Match: 0
# [Test 5000] Prediction: 0, True Class: 1, Match: 0
# [Test 5500] Prediction: 1, True Class: 1, Match: 1
#
# epoch:  5702 ;current acc:  0.6948439144159705 ;best acc:  0.6948439144159705 ;current k:  7 ;best k:  7
#
# [Test 6000] Prediction: 1, True Class: 1, Match: 1
# [Test 6500] Prediction: 1, True Class: 1, Match: 1
# [Test 7000] Prediction: 1, True Class: 1, Match: 1
# [Test 7500] Prediction: 1, True Class: 1, Match: 1
# [Test 8000] Prediction: 0, True Class: 1, Match: 0
# [Test 8500] Prediction: 1, True Class: 0, Match: 0
#
# epoch:  8553 ;current acc:  0.6913363732023617 ;best acc:  0.6948439144159705 ;current k:  9 ;best k:  7
#
# [Test 9000] Prediction: 1, True Class: 1, Match: 1
# [Test 9500] Prediction: 1, True Class: 0, Match: 0
# [Test 10000] Prediction: 1, True Class: 0, Match: 0
# [Test 10500] Prediction: 1, True Class: 1, Match: 1
# [Test 11000] Prediction: 1, True Class: 0, Match: 0
#
# epoch:  11404 ;current acc:  0.6976499473868575 ;best acc:  0.6976499473868575 ;current k:  11 ;best k:  11
#
# [Test 11500] Prediction: 1, True Class: 0, Match: 0
# [Test 12000] Prediction: 0, True Class: 0, Match: 1
